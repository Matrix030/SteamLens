# %% [markdown]
# # Top 100 AppIDs with maximum reviews

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import regexp_extract, col
import time

# %%
spark = (
    SparkSession.builder
    .appName("Top 100 Apps By Reviews")
    .master('local[*]')
    .getOrCreate()
)

line_df = spark.read.text('review_lengths.txt')

parsed_df = (
    line_df
    .withColumn("appId", regexp_extract(col("value"), r"appId\s+(\d+)", 1).cast("int"))
    .withColumn("review_count", regexp_extract(col("value"), r":\s+(\d+)", 1).cast("long"))
    .select("appId", "review_count")
)

top100_df = (
    parsed_df
    .orderBy(col("review_count").desc())
    .limit(100)
)


top100_df.show(100, truncate=False)
spark.stop()
# Out:
# +------+------------+
# |appId |review_count|
# +------+------------+
# |322330|453500      |
# |291550|383839      |
# |444090|346430      |
# |304930|343298      |
# |284160|314513      |
# |322170|278092      |
# |261550|261961      |
# |107410|222400      |
# |264710|210400      |
# |238960|209999      |
# |294100|207592      |
# |393380|206625      |
# |311210|190500      |
# |435150|184200      |
# |268910|182149      |
# |48700 |165776      |
# |49520 |152400      |
# |304390|149355      |
# |244210|148438      |
# |262060|147687      |
# |444200|147505      |
# |70    |146672      |
# |250900|139200      |
# |292030|138995      |
# |379430|138100      |
# |319630|137600      |
# |433340|136456      |
# |391220|135114      |
# |270880|133391      |
# |306130|133100      |
# |438100|131700      |
# |244850|128887      |
# |218620|127397      |
# |204360|124729      |
# |323190|121988      |
# |620   |121900      |
# |211820|121649      |
# |412020|119798      |
# |10    |117100      |
# |239140|115598      |
# |220200|114699      |
# |219740|109354      |
# |394360|106697      |
# |440900|106436      |
# |356190|106013      |
# |219150|105182      |
# |220   |103800      |
# |268500|100724      |
# |275850|99599       |
# |359320|99068       |
# |219990|99038       |
# |287700|99001       |
# |8870  |98399       |
# |418370|96214       |
# |460930|95528       |
# |232090|94700       |
# |286690|93404       |
# |466240|92989       |
# |365590|92967       |
# |389730|92398       |
# |304050|92304       |
# |241930|89878       |
# |305620|85599       |
# |311690|84481       |
# |377160|83999       |
# |397540|82200       |
# |291480|82164       |
# |234140|81913       |
# |254700|81241       |
# |108600|77899       |
# |457140|77500       |
# |214950|77200       |
# |240720|76408       |
# |397900|76247       |
# |331470|75250       |
# |203160|74600       |
# |212680|74355       |
# |239030|73527       |
# |289650|73428       |
# |218230|73425       |
# |223470|73400       |
# |223710|73170       |
# |207610|72754       |
# |35140 |72521       |
# |203770|72191       |
# |414340|71200       |
# |365670|70728       |
# |460950|70495       |
# |238320|70200       |
# |242050|69971       |
# |208650|69700       |
# |493340|69500       |
# |4000  |69296       |
# |287390|68900       |
# |55230 |68547       |
# |265930|68450       |
# |233860|68400       |
# |200260|67858       |
# |213670|67674       |
# |424370|67670       |
# +------+------------+

# %%
import pandas as pd

# %%
df = pd.read_parquet('all_reviews.parquet')
df
# Out:
#         steam_appid  required_age  is_free controller_support  \
# 0                10             0    False               None
# 1                10             0    False               None
# 2                10             0    False               None
# 3                10             0    False               None
# 4                10             0    False               None
# ...             ...           ...      ...                ...
# 235359       502370             0    False               None
# 235360       502370             0    False               None
# 235361       502370             0    False               None
# 235362       502370             0    False               None
# 235363       502370             0    False               None
#
#                                      detailed_description  \
# 0       Play the world's number 1 online action game. ...
# 1       Play the world's number 1 online action game. ...
# 2       Play the world's number 1 online action game. ...
# 3       Play the world's number 1 online action game. ...
# 4       Play the world's number 1 online action game. ...
# ...                                                   ...
# 235359  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235360  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235361  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235362  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235363  <strong>Warhammer 40,000: Sanctus Reach</stron...
#
#                                            about_the_game  \
# 0       Play the world's number 1 online action game. ...
# 1       Play the world's number 1 online action game. ...
# 2       Play the world's number 1 online action game. ...
# 3       Play the world's number 1 online action game. ...
# 4       Play the world's number 1 online action game. ...
# ...                                                   ...
# 235359  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235360  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235361  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235362  <strong>Warhammer 40,000: Sanctus Reach</stron...
# 235363  <strong>Warhammer 40,000: Sanctus Reach</stron...
#
#                                         short_description price_overview  \
# 0       Play the world's number 1 online action game. ...          $9.99
# 1       Play the world's number 1 online action game. ...          $9.99
# 2       Play the world's number 1 online action game. ...          $9.99
# 3       Play the world's number 1 online action game. ...          $9.99
# 4       Play the world's number 1 online action game. ...          $9.99
# ...                                                   ...            ...
# 235359  Warhammer 40,000: Sanctus Reach is a 3D turn-b...         $29.99
# 235360  Warhammer 40,000: Sanctus Reach is a 3D turn-b...         $29.99
# 235361  Warhammer 40,000: Sanctus Reach is a 3D turn-b...         $29.99
# 235362  Warhammer 40,000: Sanctus Reach is a 3D turn-b...         $29.99
# 235363  Warhammer 40,000: Sanctus Reach is a 3D turn-b...         $29.99
#
#         platform_windows  platform_mac  ...  ratings_nzoflc  ratings_cero  \
# 0                   True          True  ...            None          None
# 1                   True          True  ...            None          None
# 2                   True          True  ...            None          None
# 3                   True          True  ...            None          None
# 4                   True          True  ...            None          None
# ...                  ...           ...  ...             ...           ...
# 235359              True         False  ...            None          None
# 235360              True         False  ...            None          None
# 235361              True         False  ...            None          None
# 235362              True         False  ...            None          None
# 235363              True         False  ...            None          None
#
#        ratings_esrb ratings_pegi  ratings_crl  ratings_fpb  ratings_oflc  \
# 0              None         None         None         None          None
# 1              None         None         None         None          None
# 2              None         None         None         None          None
# 3              None         None         None         None          None
# 4              None         None         None         None          None
# ...             ...          ...          ...          ...           ...
# 235359         None         None         None         None          None
# 235360         None         None         None         None          None
# 235361         None         None         None         None          None
# 235362         None         None         None         None          None
# 235363         None         None         None         None          None
#
#        ratings_steam_germany  ratings_video ratings_mda
# 0                         16           None        None
# 1                         16           None        None
# 2                         16           None        None
# 3                         16           None        None
# 4                         16           None        None
# ...                      ...            ...         ...
# 235359                     6           None        None
# 235360                     6           None        None
# 235361                     6           None        None
# 235362                     6           None        None
# 235363                     6           None        None
#
# [235364 rows x 42 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32672\2495335308.py in ?()
# ----> 1 print(df.dtypes.set_option('display.max_columns'))
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'set_option'
