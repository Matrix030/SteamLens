# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm.auto import tqdm

# Set up logging
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Load all parquet files with Dask
logger.info("Loading parquet files...")
df = dd.read_parquet("parquet_output_2_extras_with_names/*.parquet")
df = df[df['review_language'] == 'english']
# Check the shape before sampling
total_rows = df.map_partitions(len).compute()
total_rows = total_rows.sum()
logger.info(f"Total rows before sampling: {total_rows}")

# Sample 10% of the data and convert to pandas
# Using random_state for reproducibility
logger.info("Sampling data...")
df_sample = df.sample(frac=0.1, random_state=42).compute()

logger.info(f"Sample shape: {df_sample.shape}")
df_sample.head()
# Out:
# INFO:__main__:Loading parquet files...
# INFO:__main__:Total rows before sampling: 17475878
# INFO:__main__:Sampling data...
# INFO:__main__:Sample shape: (1747112, 29)
#                  name  steam_appid required_age  is_free controller_support  \
# 59466  Counter-Strike           10            0    False               <NA>
# 63382  Counter-Strike           10            0    False               <NA>
# 52936  Counter-Strike           10            0    False               <NA>
# 84145  Counter-Strike           10            0    False               <NA>
# 38855  Counter-Strike           10            0    False               <NA>
#
#                                     detailed_description  \
# 59466  Play the world's number 1 online action game. ...
# 63382  Play the world's number 1 online action game. ...
# 52936  Play the world's number 1 online action game. ...
# 84145  Play the world's number 1 online action game. ...
# 38855  Play the world's number 1 online action game. ...
#
#                                           about_the_game  \
# 59466  Play the world's number 1 online action game. ...
# 63382  Play the world's number 1 online action game. ...
# 52936  Play the world's number 1 online action game. ...
# 84145  Play the world's number 1 online action game. ...
# 38855  Play the world's number 1 online action game. ...
#
#                                        short_description price_overview  \
# 59466  Play the world's number 1 online action game. ...          $9.99
# 63382  Play the world's number 1 online action game. ...          $9.99
# 52936  Play the world's number 1 online action game. ...          $9.99
# 84145  Play the world's number 1 online action game. ...          $9.99
# 38855  Play the world's number 1 online action game. ...          $9.99
#
#       metacritic_score  ... author_num_reviews author_playtime_forever  \
# 59466               88  ...                  2                  9515.0
# 63382               88  ...                  1                  1095.0
# 52936               88  ...                  7                   626.0
# 84145               88  ...                 14                   471.0
# 38855               88  ...                  1                 47189.0
#
#       author_play_time_last_two_weeks author_playtime_at_review  \
# 59466                             0.0                    9507.0
# 63382                             0.0                     637.0
# 52936                             0.0                     371.0
# 84145                             4.0                     419.0
# 38855                             0.0                    9965.0
#
#        author_last_played                                             review  \
# 59466        1.387817e+09  Would recommend anytime, best competetive FPS ...
# 63382        1.539682e+09  [table]
# [tr]
#     [td]⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀...
# 52936        1.641059e+09      Getting flamed by 20 year olds is always fun.
# 84145        1.743653e+09                                  csgo on min specs
# 38855        1.741425e+09  Лучший шутер,занимающий лидирующее место с 199...
#
#       voted_up votes_up  votes_funny  weighted_vote_score
# 59466     True        0            1             0.500000
# 63382     True        1            0             0.509804
# 52936     True        0            0             0.500000
# 84145     True        1            0             0.523810
# 38855     True        0            0             0.500000
#
# [5 rows x 29 columns]
