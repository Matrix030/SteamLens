# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from tqdm.auto import tqdm

# Set up logging
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Load all parquet files with Dask
logger.info("Loading parquet files...")
df = dd.read_parquet("parquet_output_indie/*.parquet")
df = df[df['review_language'] == 'english']
# Check the shape before sampling
total_rows = len(df)
logger.info(f"Total rows before sampling: {total_rows}")

# Sample 10% of the data and convert to pandas
# Using random_state for reproducibility
logger.info("Sampling data...")
df_sample = df.sample(frac=0.1, random_state=42).compute()

logger.info(f"Sample shape: {df_sample.shape}")
df_sample.head()
# Out:
# INFO:__main__:Loading parquet files...
# INFO:__main__:Total rows before sampling: 1368298
# INFO:__main__:Sampling data...
# INFO:__main__:Sample shape: (136827, 29)
#            name  steam_appid  required_age  is_free controller_support  \
# 86221  Terraria       105600             0    False               full
# 66016  Terraria       105600             0    False               full
# 73007  Terraria       105600             0    False               full
# 45746  Terraria       105600             0    False               full
# 54217  Terraria       105600             0    False               full
#
#                                     detailed_description  \
# 86221  Dig, Fight, Explore, Build:  The very world is...
# 66016  Dig, Fight, Explore, Build:  The very world is...
# 73007  Dig, Fight, Explore, Build:  The very world is...
# 45746  Dig, Fight, Explore, Build:  The very world is...
# 54217  Dig, Fight, Explore, Build:  The very world is...
#
#                                           about_the_game  \
# 86221  Dig, Fight, Explore, Build:  The very world is...
# 66016  Dig, Fight, Explore, Build:  The very world is...
# 73007  Dig, Fight, Explore, Build:  The very world is...
# 45746  Dig, Fight, Explore, Build:  The very world is...
# 54217  Dig, Fight, Explore, Build:  The very world is...
#
#                                        short_description price_overview  \
# 86221  Dig, fight, explore, build! Nothing is impossi...          $9.99
# 66016  Dig, fight, explore, build! Nothing is impossi...          $9.99
# 73007  Dig, fight, explore, build! Nothing is impossi...          $9.99
# 45746  Dig, fight, explore, build! Nothing is impossi...          $9.99
# 54217  Dig, fight, explore, build! Nothing is impossi...          $9.99
#
#       metacritic_score  ... author_num_reviews author_playtime_forever  \
# 86221               83  ...                 20                 20777.0
# 66016               83  ...                  1                 46559.0
# 73007               83  ...                 41                149253.0
# 45746               83  ...                 13                 84615.0
# 54217               83  ...                  3                 11037.0
#
#        author_play_time_last_two_weeks author_playtime_at_review  \
# 86221                              0.0                   18678.0
# 66016                              0.0                    8584.0
# 73007                              0.0                   46357.0
# 45746                              0.0                   82731.0
# 54217                              0.0                    5444.0
#
#        author_last_played                                             review  \
# 86221        1.611817e+09  Well for starters, I'm gonna be "THAT" guy. I ...
# 66016        1.742035e+09  TERARIA IS A FUN GAME!
# where you battle monste...
# 73007        1.725783e+09  It's like Minecraft's little sibling. Less emp...
# 45746        1.730402e+09  Didnt even particularly enjoy the gameplay, bu...
# 54217        1.739106e+09  One of the best games i have every played, the...
#
#       voted_up votes_up  votes_funny  weighted_vote_score
# 86221     True        1            0             0.523810
# 66016     True        0            1             0.500000
# 73007     True        1            0             0.529412
# 45746     True        0            0             0.500000
# 54217     True        0            0             0.500000
#
# [5 rows x 29 columns]
